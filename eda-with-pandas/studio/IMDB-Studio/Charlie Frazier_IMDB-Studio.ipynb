# %% [markdown]
# # Exploratory Data Analysis with pandas Studio
#
# ## Data Analysis of IMDB movies data
#
# #### Blocks have been created for your code
#
# #### Click on the following link and download the dataset from [Kaggle](https://www.kaggle.com/PromptCloudHQ/imdb-data).

# %% [markdown]
# ### 1. Read data

# %%
# import pandas
import pandas as pd

IMDB_Movie_Data = pd.read_csv(r"/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv")
# create your data variabe using .read_csv 

# create your data_indexed variable here
IMDB_Movie_Data
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %%
# If you are having trouble reading your file, try finding the path.  
    # Right click on your data set, on the pop-up menu select "Copy Path" then paste it into your read_csv() function.

# %%
# Read data with specified explicit index
# print(data_indexed)

import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

data_indexed = data.set_index('Title')


print(data_indexed.head())
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %% [markdown]
# ### 2. View Data
# #### As we go through this section, write your own definitions of what each function does as a comment in the code box.

# %%
# Use the head() function to view the first 5 rows of the data set
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

data_indexed = data.set_index('Title')

print (data_indexed.head(5))
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
# Use the tail() function to view the last 5 rows of the data set
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

data_indexed = data.set_index('Title')

print (data_indexed.tail(5))
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %% [markdown]
# ### 3. Understand basic information about the data
# #### As we go through this section, write your own definitions of what each function does as a comment in the code box.

# %%
# The info() function: 
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

data_indexed = data.set_index('Title')

print (data_indexed.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB
# None

# %%
# shape:
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

data_indexed = data.set_index('Title')

print("The date shape:", data_indexed.shape)

# what information does shape provide?  what is the order?
# It shows the rows and columns in the order of rows and columns.
# Out:
# The date shape: (1000, 11)

# %%
# columns:
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

data_indexed = data.set_index('Title')

print("The column data is:", data_indexed.columns.tolist())

# what information does columns provide?
# It shows us what information we have available in our columns location.
# Out:
# The column data is: ['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)', 'Metascore']

# %%
# The describe() function: 
# It's a tool used in the function's of the pandas used for statistical summarizations.

# %% [markdown]
# ### 4. Data Selection -- Indexing and Slicing

# %%
#  Extract data as series
import pandas as pd
ratings_series = data['Rating']
print(ratings_series.head())
# define and print the variable 'genre'
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

genre = data['Genre']

print(genre)
# Out:
# 0    8.1
# 1    7.0
# 2    7.3
# 3    7.2
# 4    6.2
# Name: Rating, dtype: float64
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
# Extract the data as a dataframe and print it
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

selected_columns = ['Title', 'Genre', 'Rating']
new_dataframe = date[selcted_columns]

print(new_dataframe)

# %%
# Extract data using rows
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)
row_label = data.loc[10]
print(row_label)

# loc function
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)
locate_row= data.loc[10]
print(locate_row)
# Out:
# Rank                                                                 11
# Title                           Fantastic Beasts and Where to Find Them
# Genre                                          Adventure,Family,Fantasy
# Description           The adventures of writer Newt Scamander in New...
# Director                                                    David Yates
# Actors                Eddie Redmayne, Katherine Waterston, Alison Su...
# Year                                                               2016
# Runtime (Minutes)                                                   133
# Rating                                                              7.5
# Votes                                                            232072
# Revenue (Millions)                                               234.02
# Metascore                                                          66.0
# Name: 10, dtype: object
# Rank                                                                 11
# ...

# %%
# iloc function
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)
index_locate= data.iloc[10:20]
print(index_locate)
# Out:
#     Rank                                    Title                       Genre  \
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# 12    13                                Rogue One     Action,Adventure,Sci-Fi
# 13    14                                    Moana  Animation,Adventure,Comedy
# 14    15                                 Colossal         Action,Comedy,Drama
# 15    16                  The Secret Life of Pets  Animation,Adventure,Comedy
# 16    17                            Hacksaw Ridge     Biography,Drama,History
# 17    18                             Jason Bourne             Action,Thriller
# 18    19                                     Lion             Biography,Drama
# 19    20                                  Arrival        Drama,Mystery,Sci-Fi
#
#                                           Description          Director  \
# ...

# %% [markdown]
# ### 5. Data Selection - Based on Conditional Filtering

# %%
# Use the code block to select movies that have been released between 2010-2016, with a rating of less than 6.0, but generated a signifianct (top) revenue.
import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

release_2010_2016 = data[(data['Year'] >= 2010) & (data['Year']<= 2016)]
less_than_6 = release_2010_2016[release_2010_2016['Rating'] < 6.0]
low_revenue = release_2010_2016['Revenue (Millions)'].quantile(0.90)
top_revenue = release_2010_2016[release_2010_2016['Revenue (Millions)']>= low_revenue]

print(top_revenue)
# Out:
#      Rank                                      Title  \
# 0       1                    Guardians of the Galaxy
# 3       4                                       Sing
# 4       5                              Suicide Squad
# 10     11    Fantastic Beasts and Where to Find Them
# 12     13                                  Rogue One
# ..    ...                                        ...
# 701   702                                        Ted
# 772   773                   How to Train Your Dragon
# 797   798                            Despicable Me 2
# 925   926  The Twilight Saga: Breaking Dawn - Part 1
# 941   942                 The Twilight Saga: Eclipse
#
#                           Genre  \
# 0       Action,Adventure,Sci-Fi
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
# 10     Adventure,Family,Fantasy
# 12      Action,Adventure,Sci-Fi
# ..                          ...
# 701              Comedy,Fantasy
# 772  Animation,Action,Adventure
# ...

# %%
# Note: The article is expecting more than 1 Twilight movie at the time of publishing.  
#To find the second Twilight movie, try manipulating the quantile value.  
#How specific can you get?

import pandas as pd

file_path = '/Users/charl/Desktop/LaunchCode-Data-Analysis/Data-Analysis-Projects/eda-with-pandas/studio/IMDB-Studio/IMDB-Movie-Data.csv'
data = pd.read_csv(file_path)

twilight_movies = data[data['Title'].str.contains("Twilight", case=False, na=False)]
search_twilight_movies = twilight_movies.sort_values(by='Revenue (Millions)', ascending=False)
twilight_quantile = search_twilight_movies['Revenue (Millions)'].quantile(0.50)
more_twilight_movies = search_twilight_movies[search_twilight_movies['Revenue (Millions)'].between(twilight_quantile *0.95, twilight_quantile *1.05)]

print("Mid Quantile Revenue Range", twilight_quantile)
print("Movies Near Mid Quantile Revenue Range", more_twilight_movies)
# Out:
# Mid Quantile Revenue Range 286.78999999999996
# Movies Near Mid Quantile Revenue Range      Rank                                      Title                    Genre  \
# 941   942                 The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
# 366   367  The Twilight Saga: Breaking Dawn - Part 2  Adventure,Drama,Fantasy
# 925   926  The Twilight Saga: Breaking Dawn - Part 1  Adventure,Drama,Fantasy
#
#                                            Description     Director  \
# 941  As a string of mysterious killings grips Seatt...  David Slade
# 366  After the birth of Renesmee, the Cullens gathe...  Bill Condon
# 925  The Quileutes close in on expecting parents Ed...  Bill Condon
#
#                                                 Actors  Year  \
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
# 366  Kristen Stewart, Robert Pattinson, Taylor Laut...  2012
# 925  Kristen Stewart, Robert Pattinson, Taylor Laut...  2011
#
# ...
